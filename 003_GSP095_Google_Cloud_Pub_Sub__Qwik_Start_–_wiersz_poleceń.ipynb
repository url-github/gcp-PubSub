# %% [markdown]
# [004 GSP095 Google Cloud Pub/Sub: Qwik Start – wiersz poleceń](https://www.cloudskillsboost.google/focuses/925?catalog_rank=%7B%22rank%22%3A8%2C%22num_filters%22%3A0%2C%22has_search%22%3Atrue%7D&parent=catalog&search_id=22532135)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.10.11.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.14.11.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.22.19.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 1. Tematy Pub/Sub

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.34.24.png](data:image/png;base64,...)

# %%
gcloud pubsub topics create myTopic

# %% [markdown]
# ![2023-04-30 09_43_38-Tematy – Pub_Sub – qwiklabs-gcp-02-e21… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-29 19_24_19-Topics – Pub_Sub – qwiklabs-gcp-00-160… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.36.42.png](data:image/png;base64,...)

# %%
gcloud pubsub topics create Test1

# %%
gcloud pubsub topics create Test2

# %% [markdown]
# ![2023-04-29 19_25_10-Topics – Pub_Sub – qwiklabs-gcp-00-160… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.46.30.png](data:image/png;base64,...)

# %%
gcloud pubsub topics list

# %% [markdown]
# ![2023-03-04 13_47_17-Topics – Pub_Sub – qwiklabs-gcp-04-871… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.47.15.png](data:image/png;base64,...)

# %%
gcloud pubsub topics delete Test1

# %%
gcloud pubsub topics delete Test2

# %% [markdown]
# ![2023-04-29 19_26_31-Topics – Pub_Sub – qwiklabs-gcp-00-160… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.51.04.png](data:image/png;base64,...)

# %%
gcloud pubsub topics list

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.51.50.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 2. Subskrypcje Pub/Sub

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.53.44.png](data:image/png;base64,...)

# %%
gcloud pubsub subscriptions create --topic myTopic mySubscription

# %% [markdown]
# ![2023-04-30 09_47_57-Tematy – Pub_Sub – qwiklabs-gcp-02-e21… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.56.13.png](data:image/png;base64,...)

# %%
gcloud pubsub subscriptions create --topic myTopic Test1

# %%
gcloud pubsub subscriptions create --topic myTopic Test2

# %% [markdown]
# ![2023-04-30 09_50_36-Subskrypcje – Pub_Sub – qwiklabs-gcp-02-e21… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![Zrzut ekranu 2023-02-26 o 17.58.09.png](data:image/png;base64,...)

# %%
gcloud pubsub topics list-subscriptions myTopic

# %% [markdown]
# ![2023-04-29 19_28_17-Topics – Pub_Sub – qwiklabs-gcp-00-160… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-02-27 15_12_31-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud pubsub subscriptions delete Test1

# %%
gcloud pubsub subscriptions delete Test2

# %% [markdown]
# ![2023-02-27 15_35_15-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud pubsub topics list-subscriptions myTopic

# %% [markdown]
# ![2023-02-27 15_36_15-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 3. Publikowanie i pobieranie pojedynczej wiadomości w Pub/Sub

# %% [markdown]
# ![2023-02-27 15_38_41-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud pubsub topics publish myTopic --message "Jestem Piotr V0"

# %% [markdown]
# ![2023-04-29 19_30_28-Topics – Pub_Sub – qwiklabs-gcp-00-160… – Google Cloud console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-02-27 15_41_00-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud pubsub topics publish myTopic --message "Jestem Piotr V1"

# %%
gcloud pubsub topics publish myTopic --message "Jestem Piotr V2"

# %%
gcloud pubsub topics publish myTopic --message "Jestem Piotr V3"

# %% [markdown]
# ![2023-02-27 15_45_34-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud pubsub subscriptions pull mySubscription --auto-ack

# %% [markdown]
# ![2023-04-30 09_58_24-Subskrypcje – Pub_Sub – qwiklabs-gcp-02-e21… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-02-27 15_47_44-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-04-30 10_00_21-Subskrypcje – Pub_Sub – qwiklabs-gcp-02-e21… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ##Zadanie 4. Pobieranie wszystkich wiadomości z subskrypcji za pomocą Pub/Sub

# %% [markdown]
# ![2023-02-27 15_50_43-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud pubsub topics publish myTopic --message "Jestem Piotr V4"

# %%
gcloud pubsub topics publish myTopic --message "Jestem Piotr V5"

# %%
gcloud pubsub topics publish myTopic --message "Jestem Piotr V6"

# %% [markdown]
# ![2023-02-27 15_52_52-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)

# %%
gcloud pubsub subscriptions pull mySubscription --auto-ack --limit=3

# %% [markdown]
# ![2023-04-30 10_04_58-Tematy – Pub_Sub – qwiklabs-gcp-02-e21… – Google Cloud Console.png](data:image/png;base64,...)

# %% [markdown]
# ![2023-02-27 15_54_12-Google Cloud Pub_Sub_ Qwik Start – wiersz poleceń _ Google Cloud Skills Boost.png](data:image/png;base64,...)
